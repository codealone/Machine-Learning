# %%
import graphlab

# %%
train_data = graphlab.SFrame('image_train_data/')
test_data = graphlab.SFrame('image_test_data/')
# Out:
# This non-commercial license of GraphLab Create is assigned to samriddhkulshrestha@gmail.com and will expire on March 06, 2017. For commercial licensing options, visit https://dato.com/buy/.
# 2016-06-15 00:20:22,043 [INFO] graphlab.cython.cy_server, 176: GraphLab Create v1.9 started. Logging: /tmp/graphlab_server_1465930208.log

# %%
train_data.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:43996/index.html
# Opening Canvas in default web browser.

# %%
train_data.head()
# Out:
# Columns:
# 	id	int
# 	image	Image
# 	label	str
# 	deep_features	array
# 	image_array	array
#
# Rows: 10
#
# Data:
# +-----+----------------------+------------+-------------------------------+
# |  id |        image         |   label    |         deep_features         |
# +-----+----------------------+------------+-------------------------------+
# |  24 | Height: 32 Width: 32 |    bird    | [0.242871761322, 1.0954537... |
# |  33 | Height: 32 Width: 32 |    cat     | [0.525087952614, 0.0, 0.0,... |
# |  36 | Height: 32 Width: 32 |    cat     | [0.566015958786, 0.0, 0.0,... |
# |  70 | Height: 32 Width: 32 |    dog     | [1.12979578972, 0.0, 0.0, ... |
# |  90 | Height: 32 Width: 32 |    bird    | [1.71786928177, 0.0, 0.0, ... |
# |  97 | Height: 32 Width: 32 | automobile | [1.57818555832, 0.0, 0.0, ... |
# | 107 | Height: 32 Width: 32 |    dog     | [0.0, 0.0, 0.220677852631,... |
# | 121 | Height: 32 Width: 32 |    bird    | [0.0, 0.23753464222, 0.0, ... |
# ...

# %%
knn_model = graphlab.nearest_neighbors.create(train_data,features=['deep_features'],label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
graphlab.canvas.set_target('ipynb')
cat = train_data[18:19]
cat['image'].show()

# %%
knn_model.query(cat)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 36.812ms     |
# | Done         |         | 100         | 352.58ms     |
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |       384       |      0.0      |  1   |
# |      0      |       6910      | 36.9403137951 |  2   |
# |      0      |      39777      | 38.4634888975 |  3   |
# |      0      |      36870      | 39.7559623119 |  4   |
# |      0      |      41734      | 39.7866014148 |  5   |
# +-------------+-----------------+---------------+------+
# [5 rows x 4 columns]
# ...

# %%
def get_images_from_ids(query_result):
    return train_data.filter_by(query_result['reference_label'],'id')

# %%
cat_neighbours=get_images_from_ids(knn_model.query(cat))
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 21.021ms     |
# | Done         |         | 100         | 313.881ms    |
# +--------------+---------+-------------+--------------+

# %%
cat_neighbours['image'].show()

# %%
car = train_data[8:9]
car['image'].show()

# %%
get_images_from_ids(knn_model.query(car))['image'].show()
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 24.769ms     |
# | Done         |         | 100         | 324.554ms    |
# +--------------+---------+-------------+--------------+

# %%
show_neighbours = lambda i: get_images_from_ids(knn_model.query(train_data[i:i+1]))['image'].show()

# %%
show_neighbours(8)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 16.894ms     |
# | Done         |         | 100         | 308.343ms    |
# +--------------+---------+-------------+--------------+

# %%
summary = train_data['label'].sketch_summary().frequent_items()

# %%
print summary
# Out:
# {'automobile': 509, 'dog': 509, 'bird': 478, 'cat': 509}

# %%
dog_data = train_data[train_data['label'] == 'dog']

# %%
automobile_data = train_data[train_data['label'] == 'automobile']

# %%
bird_data = train_data[train_data['label'] == 'bird']

# %%
cat_data = train_data[train_data['label'] == 'cat']

# %%
dog_model = graphlab.nearest_neighbors.create(dog_data,features=['deep_features'],label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
automobile_model = graphlab.nearest_neighbors.create(automobile_data,features=['deep_features'],label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
bird_model = graphlab.nearest_neighbors.create(bird_data,features=['deep_features'],label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
cat_model = graphlab.nearest_neighbors.create(cat_data,features=['deep_features'],label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
show_neighbours_dog = lambda i: get_images_from_ids(dog_model.query(train_data[i:i+1]))['image'].show()

# %%
show_neighbours_bird = lambda i: get_images_from_ids(bird_model.query(train_data[i:i+1]))['image'].show()

# %%
show_neighbours_automobile = lambda i: get_images_from_ids(autombile_model.query(train_data[i:i+1]))['image'].show()

# %%
show_neighbours_cat = lambda i: get_images_from_ids(cat_model.query(train_data[i:i+1]))['image'].show()

# %%
show_neighbours_cat(0)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 16.089ms     |
# | Done         |         | 100         | 114.83ms     |
# +--------------+---------+-------------+--------------+

# %%
show_neighbours_dog(0)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 19.227ms     |
# | Done         |         | 100         | 93.476ms     |
# +--------------+---------+-------------+--------------+

# %%
cat_n = cat_model.query(test_data[0:1])
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 18.237ms     |
# | Done         |         | 100         | 93.943ms     |
# +--------------+---------+-------------+--------------+

# %%
cat_n.head()
# Out:
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16289      |  34.623719208 |  1   |
# |      0      |      45646      | 36.0068799284 |  2   |
# |      0      |      32139      | 36.5200813436 |  3   |
# |      0      |      25713      | 36.7548502521 |  4   |
# |      0      |       331       | 36.8731228168 |  5   |
# +-------------+-----------------+---------------+------+
# [5 rows x 4 columns]

# %%
dog_n = dog_model.query(test_data[0:1])
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 7.092ms      |
# | Done         |         | 100         | 91.144ms     |
# +--------------+---------+-------------+--------------+

# %%
dog_n.head()
# Out:
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16976      | 37.4642628784 |  1   |
# |      0      |      13387      | 37.5666832169 |  2   |
# |      0      |      35867      | 37.6047267079 |  3   |
# |      0      |      44603      | 37.7065585153 |  4   |
# |      0      |       6094      | 38.5113254907 |  5   |
# +-------------+-----------------+---------------+------+
# [5 rows x 4 columns]

# %%
test_dog_data = test_data[test_data['label'] == 'dog']

# %%
test_automobile_data = test_data[test_data['label'] == 'automobile']

# %%
test_cat_data = test_data[test_data['label'] == 'cat']

# %%
test_bird_data = test_data[test_data['label'] == 'bird']

# %%
dog_cat_neighbors = cat_model.query(test_dog_data, k=1)
# Out:
# Starting blockwise querying.
# max rows per data block: 7668
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 127000  | 24.9509     | 579.626ms    |
# | Done         | 509000  | 100         | 595.384ms    |
# +--------------+---------+-------------+--------------+

# %%
dog_dog_neighbors = dog_model.query(test_dog_data, k=1)
# Out:
# Starting blockwise querying.
# max rows per data block: 7668
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 127000  | 24.9509     | 542.603ms    |
# | Done         | 509000  | 100         | 571.599ms    |
# +--------------+---------+-------------+--------------+

# %%
dog_bird_neighbors = bird_model.query(test_dog_data, k=1)
# Out:
# Starting blockwise querying.
# max rows per data block: 7668
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 120000  | 25.1046     | 492.372ms    |
# | Done         | 478000  | 100         | 557.512ms    |
# +--------------+---------+-------------+--------------+

# %%
dog_automobile_neighbors = automobile_model.query(test_dog_data, k=1)
# Out:
# Starting blockwise querying.
# max rows per data block: 7668
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 127000  | 24.9509     | 518.146ms    |
# | Done         | 509000  | 100         | 569.316ms    |
# +--------------+---------+-------------+--------------+

# %%
distance_dog = graphlab.SFrame({'dog_dog': dog_dog_neighbors['distance'],'dog_bird': dog_bird_neighbors['distance'],'dog_cat': dog_cat_neighbors['distance'],'dog_automobile':dog_automobile_neighbors['distance']})

# %%
distance_dog.show()

# %%
maximus = distance_dog.apply(lambda x : 1 if x['dog_dog']<x['dog_bird'] and x['dog_dog']<x['dog_automobile'] and x['dog_dog']<x['dog_cat'] else 0L)

# %%
mb = maximus.sum()

# %%
print mb
# Out:
# 678

# %%
print len(maximus)
# Out:
# 1000
